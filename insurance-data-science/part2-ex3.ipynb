# %%
import numpy as np
import pandas as pd

coef_nclaims_df = pd.read_csv("./out/coef_nclaims.txt", delimiter=";")
coef_nclaims_df.rename(lambda col_name: col_name + "_N", axis=1, inplace=True)
coef_nclaims_df
# Out:
#                 Estimate_N  Std. Error_N  t value_N    Pr(>|t|)_N
# (Intercept)      -1.679381      0.126209 -13.306391  2.489291e-40
# zoneD             0.233977      0.068960   3.392962  6.919475e-04
# zoneE             0.406756      0.070018   5.809270  6.312527e-09
# zoneF             0.415336      0.156986   2.645689  8.155014e-03
# zoneA;B          -0.165548      0.069769  -2.372787  1.765822e-02
# brand2            0.055325      0.066262   0.834944  4.037534e-01
# brand6           -0.117159      0.133800  -0.875628  3.812366e-01
# brand12          -0.133241      0.083152  -1.602375  1.090791e-01
# brand14          -0.213623      0.328277  -0.650739  5.152178e-01
# brand10;11;13     0.264279      0.097379   2.713933  6.651231e-03
# brand3;5          0.162957      0.076699   2.124625  3.362282e-02
# fuelE            -0.168853      0.050752  -3.327011  8.784631e-04
# agecut[31,41)    -0.681240      0.110608  -6.159032  7.374721e-10
# agecut[41,51)    -0.672315      0.110087  -6.107115  1.021937e-09
# agecut[51,61)    -0.795615      0.113611  -7.002971  2.537453e-12
# agecut[61,71)    -0.793542      0.127324  -6.232451  4.628475e-10
# agecut[71,81)    -0.850289      0.148074  -5.742341  9.391616e-09
# agecut[81,101)   -1.052068      0.280119  -3.755788  1.729927e-04
# agecut[25,31)    -0.576613      0.124023  -4.649223  3.340375e-06
# vehcut[4,11)      0.104307      0.064125   1.626630  1.038221e-01
# vehcut[11,16)     0.026034      0.076313   0.341154  7.329894e-01
# vehcut[16,20)    -0.219157      0.124524  -1.759960  7.842076e-02
# vehcut[20,101)   -0.123213      0.198824  -0.619708  5.354529e-01

# %%
coef_sev_df = pd.read_csv("./out/coef_sev.txt", delimiter=";")
coef_sev_df.rename(lambda col_name: col_name + "_Y", axis=1, inplace=True)
coef_sev_df
# Out:
#                 Estimate_Y  Std. Error_Y  t value_Y  Pr(>|t|)_Y
# (Intercept)       7.277705      0.091878  79.210579    0.000000
# power5           -0.075189      0.062591  -1.201280    0.229801
# power6           -0.141010      0.059376  -2.374888    0.017659
# power7           -0.102386      0.060176  -1.701434    0.089034
# power8           -0.050447      0.084812  -0.594810    0.552046
# power9           -0.276241      0.097512  -2.832880    0.004665
# power10          -0.083611      0.092518  -0.903732    0.366259
# power11          -0.110996      0.129698  -0.855803    0.392221
# power12          -0.231768      0.173883  -1.332900    0.182733
# power13           0.094797      0.220609   0.429706    0.667461
# power14          -0.071833      0.223419  -0.321518    0.747855
# power15          -0.172567      0.308752  -0.558918    0.576287
# brand2            0.043495      0.047369   0.918201    0.358637
# brand6           -0.071770      0.094593  -0.758729    0.448114
# brand12           0.127862      0.059958   2.132518    0.033099
# brand14          -0.146288      0.336617  -0.434582    0.663918
# brand10;11;13     0.024495      0.074194   0.330148    0.741326
# brand3;5         -0.042942      0.055911  -0.768034    0.442568
# agecut[31,41)    -0.210359      0.076772  -2.740059    0.006204
# agecut[41,51)    -0.166015      0.075976  -2.185100    0.029010
# agecut[51,61)    -0.148053      0.078292  -1.891038    0.058780
# agecut[61,71)    -0.247046      0.088407  -2.794428    0.005254
# agecut[71,81)    -0.011403      0.102489  -0.111257    0.911425
# agecut[81,101)   -0.315509      0.203866  -1.547629    0.121888
# agecut[25,31)    -0.267184      0.086266  -3.097221    0.001984
# vehcut[4,11)      0.053337      0.046072   1.157705    0.247138
# vehcut[11,16)    -0.004808      0.053524  -0.089837    0.928427
# vehcut[16,20)     0.231345      0.089064   2.597533    0.009466
# vehcut[20,101)   -0.173908      0.137196  -1.267584    0.205111

# %% [markdown]
# Join both dataframes by index...

# %%
def renamer_function(name):
    new_name = name
    if "(Intercept)" in name:
        new_name = "Standard Insured"
    elif "zone" in name:
        new_name = f"Zone {name[4:]}"
    elif "brand" in name:
        new_name = f"Brand {name[5:]}"
    elif "fuel" in name:
        new_name = f"Fuel {name[4:]}"
    elif "agecut" in name:
        new_name = f"Age {name[7:-1]}".replace(",","-")
    elif "vehcut" in name:
        new_name = f"Vehicle Age {name[7:-1]}".replace(",","-")
    elif "power" in name:
        new_name = f"Power {name[5:]}"
    
    #remove ; from name and return new name
    return new_name.replace(';', ' & ')

pricing_structure_df = pd.concat([coef_nclaims_df, coef_sev_df], axis=1)[['Estimate_N', 'Estimate_Y']] \
    .fillna(0) \
    .rename(columns={"Estimate_N": "beta_N", "Estimate_Y": "beta_Y"}) \
    .rename(renamer_function)
pricing_structure_df
# Out:
#                       beta_N    beta_Y
# Standard Insured   -1.679381  7.277705
# Zone D              0.233977  0.000000
# Zone E              0.406756  0.000000
# Zone F              0.415336  0.000000
# Zone A & B         -0.165548  0.000000
# Brand 2             0.055325  0.043495
# Brand 6            -0.117159 -0.071770
# Brand 12           -0.133241  0.127862
# Brand 14           -0.213623 -0.146288
# Brand 10 & 11 & 13  0.264279  0.024495
# Brand 3 & 5         0.162957 -0.042942
# Fuel E             -0.168853  0.000000
# Age 31-41          -0.681240 -0.210359
# Age 41-51          -0.672315 -0.166015
# Age 51-61          -0.795615 -0.148053
# Age 61-71          -0.793542 -0.247046
# Age 71-81          -0.850289 -0.011403
# Age 81-101         -1.052068 -0.315509
# Age 25-31          -0.576613 -0.267184
# Vehicle Age 4-11    0.104307  0.053337
# Vehicle Age 11-16   0.026034 -0.004808
# Vehicle Age 16-20  -0.219157  0.231345
# Vehicle Age 20-101 -0.123213 -0.173908
# Power 5             0.000000 -0.075189
# Power 6             0.000000 -0.141010
# Power 7             0.000000 -0.102386
# Power 8             0.000000 -0.050447
# Power 9             0.000000 -0.276241
# Power 10            0.000000 -0.083611
# Power 11            0.000000 -0.110996
# Power 12            0.000000 -0.231768
# Power 13            0.000000  0.094797
# Power 14            0.000000 -0.071833
# Power 15            0.000000 -0.172567

# %% [markdown]
# Now let's compute E(N) and E(Y)

# %%
std_beta_N, std_beta_Y = pricing_structure_df.loc['Standard Insured'][0], pricing_structure_df.loc['Standard Insured'][1]
print("Standard Insured -> ", "beta N:", std_beta_N, "; beta Y:", std_beta_Y)

def E_N(row):
    if row.name != "Standard Insured":
        return np.exp(row.beta_N + std_beta_N)
    else:
        return np.exp(std_beta_N)
    
def E_Y(row):
    if row.name != "Standard Insured":
        return np.exp(row.beta_Y + std_beta_Y)
    else:
        return np.exp(std_beta_Y)

    
pricing_structure_df['E(N)'] = pricing_structure_df.apply(E_N, axis=1)
pricing_structure_df['E(Y)'] = pricing_structure_df.apply(E_Y, axis=1)
pricing_structure_df
# Out:
# Standard Insured ->  beta N: -1.67938083008443 ; beta Y: 7.27770480397245
#                       beta_N    beta_Y      E(N)         E(Y)
# Standard Insured   -1.679381  7.277705  0.186489  1447.661542
# Zone D              0.233977  0.000000  0.235651  1447.661542
# Zone E              0.406756  0.000000  0.280095  1447.661542
# Zone F              0.415336  0.000000  0.282509  1447.661542
# Zone A & B         -0.165548  0.000000  0.158037  1447.661542
# Brand 2             0.055325  0.043495  0.197098  1512.016551
# Brand 6            -0.117159 -0.071770  0.165872  1347.403572
# Brand 12           -0.133241  0.127862  0.163226  1645.117198
# Brand 14           -0.213623 -0.146288  0.150619  1250.648104
# Brand 10 & 11 & 13  0.264279  0.024495  0.242901  1483.559992
# Brand 3 & 5         0.162957 -0.042942  0.219495  1386.812056
# Fuel E             -0.168853  0.000000  0.157515  1447.661542
# Age 31-41          -0.681240 -0.210359  0.094362  1173.029869
# Age 41-51          -0.672315 -0.166015  0.095208  1226.218108
# Age 51-61          -0.795615 -0.148053  0.084163  1248.441691
# Age 61-71          -0.793542 -0.247046  0.084338  1130.774814
# Age 71-81          -0.850289 -0.011403  0.079685  1431.248200
# Age 81-101         -1.052068 -0.315509  0.065125  1055.949820
# Age 25-31          -0.576613 -0.267184  0.104769  1108.231303
# Vehicle Age 4-11    0.104307  0.053337  0.206992  1526.972344
# Vehicle Age 11-16   0.026034 -0.004808  0.191408  1440.717253
# Vehicle Age 16-20  -0.219157  0.231345  0.149787  1824.479941
# Vehicle Age 20-101 -0.123213 -0.173908  0.164871  1216.577451
# Power 5             0.000000 -0.075189  0.186489  1342.804767
# Power 6             0.000000 -0.141010  0.186489  1257.265720
# Power 7             0.000000 -0.102386  0.186489  1306.777278
# Power 8             0.000000 -0.050447  0.186489  1376.442630
# Power 9             0.000000 -0.276241  0.186489  1098.240038
# Power 10            0.000000 -0.083611  0.186489  1331.542912
# Power 11            0.000000 -0.110996  0.186489  1295.574184
# Power 12            0.000000 -0.231768  0.186489  1148.183492
# Power 13            0.000000  0.094797  0.186489  1591.610793
# Power 14            0.000000 -0.071833  0.186489  1347.318154
# Power 15            0.000000 -0.172567  0.186489  1218.209528

# %% [markdown]
# Now computing the pure premium is just multiplying the two expected values:

# %%
pricing_structure_df['Pure Premium'] = pricing_structure_df['E(N)'] * pricing_structure_df['E(Y)']
pricing_structure_df
# Out:
#                       beta_N    beta_Y      E(N)         E(Y)  Pure Premium
# Standard Insured   -1.679381  7.277705  0.186489  1447.661542    269.973545
# Zone D              0.233977  0.000000  0.235651  1447.661542    341.142808
# Zone E              0.406756  0.000000  0.280095  1447.661542    405.483232
# Zone F              0.415336  0.000000  0.282509  1447.661542    408.977522
# Zone A & B         -0.165548  0.000000  0.158037  1447.661542    228.783562
# Brand 2             0.055325  0.043495  0.197098  1512.016551    298.014855
# Brand 6            -0.117159 -0.071770  0.165872  1347.403572    223.496230
# Brand 12           -0.133241  0.127862  0.163226  1645.117198    268.525398
# Brand 14           -0.213623 -0.146288  0.150619  1250.648104    188.371006
# Brand 10 & 11 & 13  0.264279  0.024495  0.242901  1483.559992    360.357973
# Brand 3 & 5         0.162957 -0.042942  0.219495  1386.812056    304.398827
# Fuel E             -0.168853  0.000000  0.157515  1447.661542    228.028570
# Age 31-41          -0.681240 -0.210359  0.094362  1173.029869    110.688958
# Age 41-51          -0.672315 -0.166015  0.095208  1226.218108    116.745215
# Age 51-61          -0.795615 -0.148053  0.084163  1248.441691    105.073035
# Age 61-71          -0.793542 -0.247046  0.084338  1130.774814     95.367233
# Age 71-81          -0.850289 -0.011403  0.079685  1431.248200    114.049497
# Age 81-101         -1.052068 -0.315509  0.065125  1055.949820     68.768625
# Age 25-31          -0.576613 -0.267184  0.104769  1108.231303    116.108726
# Vehicle Age 4-11    0.104307  0.053337  0.206992  1526.972344    316.071475
# Vehicle Age 11-16   0.026034 -0.004808  0.191408  1440.717253    275.765268
# Vehicle Age 16-20  -0.219157  0.231345  0.149787  1824.479941    273.284252
# Vehicle Age 20-101 -0.123213 -0.173908  0.164871  1216.577451    200.577980
# Power 5             0.000000 -0.075189  0.186489  1342.804767    250.418867
# Power 6             0.000000 -0.141010  0.186489  1257.265720    234.466741
# Power 7             0.000000 -0.102386  0.186489  1306.777278    243.700122
# Power 8             0.000000 -0.050447  0.186489  1376.442630    256.691972
# Power 9             0.000000 -0.276241  0.186489  1098.240038    204.810136
# Power 10            0.000000 -0.083611  0.186489  1331.542912    248.318651
# Power 11            0.000000 -0.110996  0.186489  1295.574184    241.610864
# Power 12            0.000000 -0.231768  0.186489  1148.183492    214.124061
# Power 13            0.000000  0.094797  0.186489  1591.610793    296.818556
# Power 14            0.000000 -0.071833  0.186489  1347.318154    251.260566
# Power 15            0.000000 -0.172567  0.186489  1218.209528    227.183175

# %% [markdown]
# Computing the tariff is simply computing how much does the insurance goes up or down depending on feature:

# %%
std_tariff = pricing_structure_df.loc['Standard Insured'][4]

def tarrif(row):
    pp = row['Pure Premium']
    if row.name != "Standard Insured":
        return pp/std_tariff
    else:
        return pp
    
pricing_structure_df['Tariff'] = pricing_structure_df.apply(tarrif, axis=1)
pricing_structure_df
# Out:
#                       beta_N    beta_Y      E(N)         E(Y)  Pure Premium  \
# Standard Insured   -1.679381  7.277705  0.186489  1447.661542    269.973545
# Zone D              0.233977  0.000000  0.235651  1447.661542    341.142808
# Zone E              0.406756  0.000000  0.280095  1447.661542    405.483232
# Zone F              0.415336  0.000000  0.282509  1447.661542    408.977522
# Zone A & B         -0.165548  0.000000  0.158037  1447.661542    228.783562
# Brand 2             0.055325  0.043495  0.197098  1512.016551    298.014855
# Brand 6            -0.117159 -0.071770  0.165872  1347.403572    223.496230
# Brand 12           -0.133241  0.127862  0.163226  1645.117198    268.525398
# Brand 14           -0.213623 -0.146288  0.150619  1250.648104    188.371006
# Brand 10 & 11 & 13  0.264279  0.024495  0.242901  1483.559992    360.357973
# Brand 3 & 5         0.162957 -0.042942  0.219495  1386.812056    304.398827
# Fuel E             -0.168853  0.000000  0.157515  1447.661542    228.028570
# Age 31-41          -0.681240 -0.210359  0.094362  1173.029869    110.688958
# Age 41-51          -0.672315 -0.166015  0.095208  1226.218108    116.745215
# Age 51-61          -0.795615 -0.148053  0.084163  1248.441691    105.073035
# Age 61-71          -0.793542 -0.247046  0.084338  1130.774814     95.367233
# Age 71-81          -0.850289 -0.011403  0.079685  1431.248200    114.049497
# Age 81-101         -1.052068 -0.315509  0.065125  1055.949820     68.768625
# Age 25-31          -0.576613 -0.267184  0.104769  1108.231303    116.108726
# Vehicle Age 4-11    0.104307  0.053337  0.206992  1526.972344    316.071475
# Vehicle Age 11-16   0.026034 -0.004808  0.191408  1440.717253    275.765268
# Vehicle Age 16-20  -0.219157  0.231345  0.149787  1824.479941    273.284252
# Vehicle Age 20-101 -0.123213 -0.173908  0.164871  1216.577451    200.577980
# Power 5             0.000000 -0.075189  0.186489  1342.804767    250.418867
# Power 6             0.000000 -0.141010  0.186489  1257.265720    234.466741
# Power 7             0.000000 -0.102386  0.186489  1306.777278    243.700122
# Power 8             0.000000 -0.050447  0.186489  1376.442630    256.691972
# Power 9             0.000000 -0.276241  0.186489  1098.240038    204.810136
# Power 10            0.000000 -0.083611  0.186489  1331.542912    248.318651
# Power 11            0.000000 -0.110996  0.186489  1295.574184    241.610864
# Power 12            0.000000 -0.231768  0.186489  1148.183492    214.124061
# Power 13            0.000000  0.094797  0.186489  1591.610793    296.818556
# Power 14            0.000000 -0.071833  0.186489  1347.318154    251.260566
# Power 15            0.000000 -0.172567  0.186489  1218.209528    227.183175
#
#                         Tariff
# Standard Insured    269.973545
# Zone D                1.263616
# Zone E                1.501937
# Zone F                1.514880
# Zone A & B            0.847430
# Brand 2               1.103867
# Brand 6               0.827845
# Brand 12              0.994636
# Brand 14              0.697739
# Brand 10 & 11 & 13    1.334790
# Brand 3 & 5           1.127514
# Fuel E                0.844633
# Age 31-41             0.409999
# Age 41-51             0.432432
# Age 51-61             0.389198
# Age 61-71             0.353247
# Age 71-81             0.422447
# Age 81-101            0.254724
# Age 25-31             0.430074
# Vehicle Age 4-11      1.170750
# Vehicle Age 11-16     1.021453
# Vehicle Age 16-20     1.012263
# Vehicle Age 20-101    0.742954
# Power 5               0.927568
# Power 6               0.868480
# Power 7               0.902681
# Power 8               0.950804
# Power 9               0.758630
# Power 10              0.919789
# Power 11              0.894943
# Power 12              0.793130
# Power 13              1.099436
# Power 14              0.930686
# Power 15              0.841502

# %% [markdown]
# Export to csv for analysis:

# %%
pricing_structure_df.to_csv("./out/part2-ex3-pricing_structure.csv")
